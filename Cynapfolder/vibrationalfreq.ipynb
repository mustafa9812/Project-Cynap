# %%
# Testing the AmesPAHdb class from amespahdbpythonsuite and readibility of the XML file
from amespahdbpythonsuite.amespahdb import AmesPAHdb
pahdb = AmesPAHdb(filename='/Users/Mustafa/Documents/GitHub/Project-Cynap/Cynapfolder/pahdb-selection-theoretical-v3.20_o883kau2kcfj4kTMhZ0.xml', cache=True, check=False)
# Out:
# =========================================================
#                  AmesPAHdbPythonSuite
#
#                           by
#
#                 Dr. Christiaan Boersma
#
#                           and
#
#              Dr. Alexandros Maragkoudakis
#
#                Dr. Matthew J. Shannanon
#
#                   Dr. Joseph E. Roser
#
# =========================================================
#
# =========================================================
#           SUITE VERSION: 0.5.0.post75+g22706ce
# =========================================================
#
# =========================================================
#            WEBSITE: WWW.ASTROCHEM.ORG/PAHDB/
# =========================================================
#
# =========================================================
#           CONTACT: CHRISTIAAN.BOERSMA@NASA.GOV
# =========================================================
#
# =========================================================
#              RESTORING DATABASE FROM CACHE
# =========================================================
#
# ==
# FILENAME                    : C:\Users\Mustafa\AppData\Local\Temp/18788fe2f63cd5bfef51b33c480056ff.pkl
# ORIGNINAL FILENAME          : /Users/Mustafa/Documents/GitHub/Project-Cynap/Cynapfolder/pahdb-selection-theoretical-v3.20_o883kau2kcfj4kTMhZ0.xml
# PARSE TIME                  : 0:00:00.000804
# DATABASE                    : theoretical
# VERSION (DATE)              : 3.20 (2019-09-12)
# COMMENT                     :
#
# This is the NASA Ames PAH IR Spectroscopic Database. The contents of
# the database are described in Bauschlicher et al. (2010), Boersma et
# al. (2014) and Mattioda et al. (2020). The database website is located
# at https://www.astrochemistry.org/pahdb/.
#
# You are kindly asked to cite the following papers when using the database:
#
#     Boersma, C., Bauschlicher, C.W., Jr., Ricca, A., Mattioda, A. L.,
#     Cami, J., Peeters, E., Sánchez de Armas, F., Puerta Saborido, G.,
#     Hudgins, D M., and Allamandola, L.J., "The NASA Ames PAH IR Spectroscopic
#     database version 2.00: updated content, website and on/offline tools",
#     2014, The Astrophysical Journal Supplement Series, 211, 8
#
#     A copy of the paper can be downloaded from NASA&apos;s ADS services:
#
#     https://ui.adsabs.harvard.edu/abs/2014ApJS..211....8B
#
#     Bauschlicher, C.W., Jr., Boersma, C., Ricca, A., Mattioda, A. L.,
#     Cami, J., Peeters, E., Sánchez de Armas, F., Puerta Saborido, G.,
#     Hudgins, D M., and Allamandola, L.J., "The NASA Ames Polycyclic
#     Aromatic Hydrocarbon Infrared Spectroscopic Database: The Computed
#     Spectra", 2010, The Astrophysical Journal Supplement Series, 189, 341
#
#     A copy of the paper can be downloaded from NASA&apos;s ADS services:
#
#     https://ui.adsabs.harvard.edu/abs/2010ApJS..189..341B
#
#     Mattioda, A.L., Hudgins, D.M., Boersma, C., Ricca, A., Peeters,
#     E., Cami, J., Sánches de Armas, F., Puerta Saborido, G.,
#     Bauschlicher, C W., J., and Allamandola, L.J. "The Nasa Ames PAH
#     IR Spectroscopic Database: The Laboratory Spectra", 2020, The
#     Astrophysical Journal Supplement Series, 251, 22
#
#     A copy of the paper can be downloaded from NASA&apos;s ADS services:
#
#     https://ui.adsabs.harvard.edu/abs/2020ApJS..251...22M
#
#     Also see https://www.astrochemistry.org/pahdb/theoretical/3.20/help/citation.
# Notes:
#     Version 3.20 adds a large number of totally resonant sextet
# (TRS) PAHs, denoted as "Clar PAHs" for simplicity, containing
# armchair edges with a number of carbons ranging from 18 up to
# 150. The spectra of both neutral and charged (cations and anions)
# Clar PAHs are added.
#
# Version 3.10 (internal) added the PAHs containing only straight edges
# as described in Ricca et al. (2018), which include even-carbon
# (neutral and charged) PAHs ranging in size from C₂₂H₁₂ to C₁₄₈H₃₀ and
# odd-carbon (neutral and charged) PAHs ranging in size from C₃₁H₁₅ to
# C₁₂₇H₃₁.
#
# Version 3.00 introduced multiple scale factors and has the Gaussian
# options for each run are more fully described. A large number of new
# species were added, including species with 5- and 7- membered rings,
# additional oval species, species with bay regions, species with side
# groups, some acridene species, and the neutral species from Mackie et
# al. (2015), with 1525 CnHm and 803 fully dehydrogenates
# species.
#
# ==
